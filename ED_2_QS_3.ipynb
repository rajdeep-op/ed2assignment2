# %%
import numpy as np
import matplotlib.pyplot as plt

q=1.0
a=0.3
c=1.0
beta=np.array([0.1,0.9,0.999])

theta=np.linspace(-np.pi, np.pi,5000)
mu=np.cos(theta)

gamma1=1/np.sqrt(1-beta[0]**2)
pow1=(1/(1-beta[0]*mu)**4)*(1-(((np.sin(theta))**2)*(np.cos(phi))**2)/((gamma1**2)*(1-beta[0]*mu)**2))
r1=pow1/np.max(pow1)

gamma2=1/np.sqrt(1-beta[1]**2)
pow2=(1/(1-beta[1]*mu)**4)*(1-(((np.sin(theta))**2)*(np.cos(phi))**2)/((gamma2**2)*(1-beta[1]*mu)**2))
r2=pow2/np.max(pow2)

gamma3=1/np.sqrt(1-beta[2]**2)
pow3=(1/(1-beta[2]*mu)**4)*(1-(((np.sin(theta))**2)*(np.cos(phi))**2)/((gamma3**2)*(1-beta[2]*mu)**2))
r3=pow3/np.max(pow3)

fig=plt.figure(figsize=(6,6))
ax=fig.add_subplot(111,polar=True)
ax.plot(theta,r1,label=r'$\beta=0.1c$')
ax.plot(theta,r2,label=r'$\beta=0.9c$')
ax.plot(theta,r3,label=r'$\beta=0.999c$')
ax.set_title(r'$\frac{dP_\perp}{d\Omega}$ vs $\theta$', size=20)
ax.legend(loc='upper left')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

q=1.0
a=0.9
c=1.0
beta=np.array([0.1,0.9,0.999])

theta=np.linspace(-np.pi,np.pi,500)
mu=np.cos(theta)

pow1=(1/(1-beta[0]*mu)**6)*((np.sin(theta))**2)
r1=pow1/np.max(pow1)

pow2=(1/(1-beta[1]*mu)**6)*((np.sin(theta))**2)
r2=pow2/np.max(pow2)

pow3=(1/(1-beta[2]*mu)**6)*((np.sin(theta))**2)
r3=pow3/np.max(pow3)

fig=plt.figure(figsize=(6,6))
ax=fig.add_subplot(111,polar=True)
ax.plot(theta,r1,label=r'$\beta=0.1c$')
ax.plot(theta,r2,label=r'$\beta=0.9c$')
ax.plot(theta,r3,label=r'$\beta=0.999c$')
ax.set_title(r'$\frac{dP_\parallel}{d\Omega}$ vs $\theta$',size=20)
ax.legend(loc='upper left')
plt.show()
